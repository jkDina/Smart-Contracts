# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Аксессуары туризм1.xlsx')

# %%
df.head(20)
# Out:
#      Артикул             Бренд                         Название  \
# 0   22049092               STC  Палки для скандинавской ходьбы
# 1   18614077            Gekars   Палки для скандинавской ходьбы
# 2   18960301               STC  Палки для скандинавской ходьбы
# 3   23853096              BONN                            Гамак
# 4   18905717          FineCase                    Электрошокер
# 5   17781485     Hunts Leaders                              Нож
# 6   18674928  Оранжевое яблоко                 Налобный фонарь
# 7    9126669         Brandcamp                           Лопата
# 8   21044132       Sale & Sale                 Налобный фонарь
# 9   14301000          FineCase                          Фонарь
# 10  19494744         1st Light                 Налобный фонарь
# 11  11298675        Cold Steel                             Нож
# 12  19467549         1st Light                          Фонарь
# 13  10424437           Steiner                         Бинокль
# ...

# %%
df.columns
# Out:
# Index(['Артикул', 'Бренд', 'Название', 'Продавец', 'Цена с промокодом',
#        'Цена со скидкой', 'Цена', 'Отзывов', 'Рейтинг', 'Первый отзыв',
#        'Вопросов', 'Покупок', 'Доступные размеры', 'Все размеры', 'Цвет',
#        'Остатки по складам', 'Остатки по размерам', 'Остатки (общее)',
#        'Параметры', 'Описание', 'Ссылка', 'Ссылки на фото'],
#       dtype='object')

# %%
df = df[['Продавец', 'Название', 'Цена с промокодом', 'Цена со скидкой', 'Цена', 'Отзывов', 'Рейтинг', 'Вопросов', 'Покупок']]

# %%
df.head()
# Out:
#                                             Продавец  \
# 0                    Черкасских Олег Владимирович ИП
# 1                    Черкасских Олег Владимирович ИП
# 2                    Черкасских Олег Владимирович ИП
# 3  Индивидуальный предприниматель Родькин Алексей...
# 4                      Прохоров Андрей Дмитриевич ИП
#
#                           Название  Цена с промокодом  Цена со скидкой  Цена  \
# 0  Палки для скандинавской ходьбы                1183             1220  5085
# 1   Палки для скандинавской ходьбы                960              990  3000
# 2  Палки для скандинавской ходьбы                1183             1220  5085
# 3                            Гамак               1554             1554  2990
# 4                    Электрошокер                 787             1250  2500
#
#    Отзывов  Рейтинг  Вопросов  Покупок
# 0       85      4.3         0      300
# 1       71      4.2         0      800
# 2       85      4.3         0     1600
# ...

# %%
#сделать новую колонку цена* покупок

# %%
df['Оборот'] = df['Цена с промокодом'] * df['Покупок']

# %%
df.head()
# Out:
#                                             Продавец  \
# 0                    Черкасских Олег Владимирович ИП
# 1                    Черкасских Олег Владимирович ИП
# 2                    Черкасских Олег Владимирович ИП
# 3  Индивидуальный предприниматель Родькин Алексей...
# 4                      Прохоров Андрей Дмитриевич ИП
#
#                           Название  Цена с промокодом  Цена со скидкой  Цена  \
# 0  Палки для скандинавской ходьбы                1183             1220  5085
# 1   Палки для скандинавской ходьбы                960              990  3000
# 2  Палки для скандинавской ходьбы                1183             1220  5085
# 3                            Гамак               1554             1554  2990
# 4                    Электрошокер                 787             1250  2500
#
#    Отзывов  Рейтинг  Вопросов  Покупок   Оборот
# 0       85      4.3         0      300   354900
# 1       71      4.2         0      800   768000
# ...

# %%
df = df.sort_values(by=['Оборот'], ascending=False)

# %%
df.head(20)
# Out:
#                                               Продавец  \
# 7                  Кудряшов Григорий Константинович ИП
# 73                              АРГОС ООО (7816135125)
# 14                         Зверев Даниил Эдуардович ИП
# 20   Общество с ограниченной ответственностью "МЕРК...
# 18   Общество с ограниченной ответственностью "МЕРК...
# 91                                             ООО МИР
# 2                      Черкасских Олег Владимирович ИП
# 33                         Зверев Даниил Эдуардович ИП
# 116                                            ООО МИР
# 48   Общество с ограниченной ответственностью "МЕРК...
# 46                         Зверев Даниил Эдуардович ИП
# 71   Общество с ограниченной ответственностью "МЕРК...
# 57   Общество с ограниченной ответственностью "МЕРК...
# 77   Общество с ограниченной ответственностью "МЕРК...
# 69   Общество с ограниченной ответственностью "МЕРК...
# 9                        Прохоров Андрей Дмитриевич ИП
# ...

# %% [markdown]
# ### First

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
turnover = df['Оборот']
del df['Оборот']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Оборот'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ee76ee57e4cf> in <module>
# ----> 1 turnover = df['Оборот']
# ...

# %%
df = pd.get_dummies(df, columns= ['Продавец', 'Название'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-e5fec399bd53> in <module>
# ----> 1 df = pd.get_dummies(df, columns= ['Продавец', 'Название'])
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     841             raise TypeError("Input must be a list-like for parameter `columns`")
#     842         else:
# --> 843             data_to_encode = data[columns]
#     844
#     845         # validate prefixes and separator to avoid silently dropping cols
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
# ...

# %%
X_train =  df.values
y_train = turnover.values

# %%
#X_train, X_test, y_train, y_test = train_test_split(df, turnover, test_size=0.01)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-7.20997859e+01,  8.52001241e+01, -8.90455602e+00, -2.24144811e+03,
#         1.73506021e+04,  1.38556468e+04,  3.75716674e+02,  4.01614396e+06,
#        -2.64335341e+05, -5.53222789e+04, -4.75879533e+05, -8.25929865e+04,
#        -1.44093451e+05, -5.52410148e+05, -3.68095292e+05, -3.27298231e+05,
#        -1.31927520e+05, -2.64629837e+05, -1.99960812e+05, -1.68816301e+05,
#        -1.77944608e+05, -5.44315754e+05, -2.04027289e+05,  4.09649349e+04,
#         4.07893665e+04,  3.58847943e+06, -1.17720504e+05, -2.06873964e+05,
#        -9.28738612e+04, -3.73575824e+05, -1.16880510e+05, -2.67967746e+05,
#        -3.46916987e+05, -1.63139141e+05,  1.31975921e+06, -1.19264496e+05,
#        -1.33002165e+05, -1.69696572e+06,  2.51295537e+05, -2.46282708e+05,
#        -2.23214925e+05,  1.53777476e+05, -3.17005866e+05,  1.17702292e+05,
#         1.61427975e+05, -7.12671119e+04, -4.44352625e+05, -1.15403148e+05,
# ...

# %%
importance = model.coef_

# %%
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.2f' % (i,v))
# Out:
# Feature: 0, Score: -72.10
# Feature: 1, Score: 85.20
# Feature: 2, Score: -8.90
# Feature: 3, Score: -2241.45
# Feature: 4, Score: 17350.60
# Feature: 5, Score: 13855.65
# Feature: 6, Score: 375.72
# Feature: 7, Score: 4016143.96
# Feature: 8, Score: -264335.34
# Feature: 9, Score: -55322.28
# Feature: 10, Score: -475879.53
# Feature: 11, Score: -82592.99
# Feature: 12, Score: -144093.45
# Feature: 13, Score: -552410.15
# Feature: 14, Score: -368095.29
# Feature: 15, Score: -327298.23
# Feature: 16, Score: -131927.52
# Feature: 17, Score: -264629.84
# Feature: 18, Score: -199960.81
# Feature: 19, Score: -168816.30
# Feature: 20, Score: -177944.61
# Feature: 21, Score: -544315.75
# Feature: 22, Score: -204027.29
# Feature: 23, Score: 40964.93
# Feature: 24, Score: 40789.37
# Feature: 25, Score: 3588479.43
# Feature: 26, Score: -117720.50
# Feature: 27, Score: -206873.96
# Feature: 28, Score: -92873.86
# Feature: 29, Score: -373575.82
# Feature: 30, Score: -116880.51
# ...

# %%
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %% [markdown]
# ### Second

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Аксессуары туризм1.xlsx')

# %%
df.columns
# Out:
# Index(['Артикул', 'Бренд', 'Название', 'Продавец', 'Цена с промокодом',
#        'Цена со скидкой', 'Цена', 'Отзывов', 'Рейтинг', 'Первый отзыв',
#        'Вопросов', 'Покупок', 'Доступные размеры', 'Все размеры', 'Цвет',
#        'Остатки по складам', 'Остатки по размерам', 'Остатки (общее)',
#        'Параметры', 'Описание', 'Ссылка', 'Ссылки на фото'],
#       dtype='object')

# %%
df['Оборот'] = df['Цена с промокодом'] * df['Покупок']

# %%
#df = df[['Продавец', 'Название', 'Цена с промокодом', 'Цена со скидкой', 'Цена', 'Отзывов', 'Рейтинг', 'Вопросов', 'Покупок']]
#df = df[['Цена с промокодом', 'Цена со скидкой', 'Цена', 'Отзывов', 'Рейтинг', 'Вопросов', 'Покупок']]
df = df[['Цена с промокодом', 'Отзывов', 'Рейтинг', 'Вопросов', 'Оборот']]

# %%
#df['Оборот'] = df['Цена с промокодом'] * df['Покупок']

# %%
df = df.sort_values(by=['Оборот'], ascending=False)

# %%
df.head()
# Out:
#     Цена с промокодом  Отзывов  Рейтинг  Вопросов   Оборот
# 7               15750       30      5.0        22  6300000
# 73               1990      162      4.8        51  5771000
# 14                274      563      4.4        63  2493400
# 20                812      186      4.8        30  2436000
# 18               1471      109      4.8        23  2353600

# %%
df
# Out:
#      Цена с промокодом  Отзывов  Рейтинг  Вопросов   Оборот
# 7                15750       30      5.0        22  6300000
# 73                1990      162      4.8        51  5771000
# 14                 274      563      4.4        63  2493400
# 20                 812      186      4.8        30  2436000
# 18                1471      109      4.8        23  2353600
# ..                 ...      ...      ...       ...      ...
# 108               1110        4      4.2         0    22200
# 82                1068        2      5.0         0    10680
# 96                1580        3      5.0         0     9480
# 139                957        5      5.0         0     5742
# 87                 779        3      5.0         0     4674
#
# [150 rows x 5 columns]

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
turnover = df['Оборот']
del df['Оборот']

# %%
#df = pd.get_dummies(df, columns= ['Продавец', 'Название'])

# %%
X_train =  df.values
y_train = turnover.values

# %%
#X_train, X_test, y_train, y_test = train_test_split(df, turnover, test_size=0.01)

# %%
forest = ExtraTreesClassifier(n_estimators=250, random_state=0)
forest.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(n_estimators=250, random_state=0)

# %%
forest.feature_importances_
# Out:
# array([0.33667077, 0.27977075, 0.19469771, 0.18886077])

# %%
importances = forest.feature_importances_

# %%
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 0 (0.336671)
# 2. feature 1 (0.279771)
# 3. feature 2 (0.194698)
# 4. feature 3 (0.188861)

# %%
plt.figure()
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X_train.shape[1]), indices)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %% [markdown]
# 0 Цена с промокодом
#
# 1 Отзывов
#
# 2 Рейтинг
#
# 3 Вопросов
#
# 4 Покупок

# %% [markdown]
# Feature importances
#
# 0 Цена с промокодом
# 1 Отзывов
# 4 Покупок
# 2 Рейтинг
# 3 Вопросов

# %% [markdown]
# ### Third

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Аксессуары туризм1.xlsx')

# %%
df.head()
# Out:
#     Артикул     Бренд                         Название  \
# 0  22049092       STC  Палки для скандинавской ходьбы
# 1  18614077    Gekars   Палки для скандинавской ходьбы
# 2  18960301       STC  Палки для скандинавской ходьбы
# 3  23853096      BONN                            Гамак
# 4  18905717  FineCase                    Электрошокер
#
#                                             Продавец  Цена с промокодом  \
# 0                    Черкасских Олег Владимирович ИП               1183
# 1                    Черкасских Олег Владимирович ИП                960
# 2                    Черкасских Олег Владимирович ИП               1183
# 3  Индивидуальный предприниматель Родькин Алексей...               1554
# 4                      Прохоров Андрей Дмитриевич ИП                787
#
#    Цена со скидкой  Цена  Отзывов  Рейтинг         Первый отзыв  ...  \
# 0             1220  5085       85      4.3  Опция не подключена  ...
# ...

# %%
df['Оборот'] = df['Цена с промокодом'] * df['Покупок']

# %%
df['Оборот']
# Out:
# 0       354900
# 1       768000
# 2      1892800
# 3        31080
# 4       629600
#         ...
# 145     383000
# 146     337700
# 147     104880
# 148     303800
# 149      91670
# Name: Оборот, Length: 150, dtype: int64

# %%
df.columns
# Out:
# Index(['Артикул', 'Бренд', 'Название', 'Продавец', 'Цена с промокодом',
#        'Цена со скидкой', 'Цена', 'Отзывов', 'Рейтинг', 'Первый отзыв',
#        'Вопросов', 'Покупок', 'Доступные размеры', 'Все размеры', 'Цвет',
#        'Остатки по складам', 'Остатки по размерам', 'Остатки (общее)',
#        'Параметры', 'Описание', 'Ссылка', 'Ссылки на фото', 'Оборот'],
#       dtype='object')

# %%
df[['Цена с промокодом', 'Отзывов', 'Рейтинг']]
# Out:
#      Цена с промокодом  Отзывов  Рейтинг
# 0                 1183       85      4.3
# 1                  960       71      4.2
# 2                 1183       85      4.3
# 3                 1554        1      2.0
# 4                  787       63      4.4
# ..                 ...      ...      ...
# 145                766       37      4.6
# 146               3377       26      4.2
# 147               1311        9      5.0
# 148               1519       11      4.7
# 149               9167        5      4.0
#
# [150 rows x 3 columns]

# %%
#df = df[['Цена с промокодом', 'Отзывов', 'Рейтинг', 'Вопросов', 'Продавец', 'Название', 'Оборот']]
df = df[['Цена с промокодом', 'Отзывов', 'Рейтинг', 'Вопросов', 'Название', 'Оборот']]

# %%
df = df[['Цена с промокодом', 'Отзывов', 'Рейтинг', 'Вопросов', 'Название', 'Оборот']]
df
# Out:
#      Цена с промокодом  Отзывов  Рейтинг  Вопросов  \
# 0                 1183       85      4.3         0
# 1                  960       71      4.2         0
# 2                 1183       85      4.3         0
# 3                 1554        1      2.0         0
# 4                  787       63      4.4         0
# ..                 ...      ...      ...       ...
# 145                766       37      4.6         7
# 146               3377       26      4.2         9
# 147               1311        9      5.0         5
# 148               1519       11      4.7         7
# 149               9167        5      4.0         5
#
#                             Название   Оборот
# 0    Палки для скандинавской ходьбы    354900
# 1     Палки для скандинавской ходьбы   768000
# 2    Палки для скандинавской ходьбы   1892800
# 3                              Гамак    31080
# 4                      Электрошокер    629600
# ..                               ...      ...
# ...

# %%
df.head()
# Out:
#    Цена с промокодом  Отзывов  Рейтинг  Вопросов  \
# 0               1183       85      4.3         0
# 1                960       71      4.2         0
# 2               1183       85      4.3         0
# 3               1554        1      2.0         0
# 4                787       63      4.4         0
#
#                           Название   Оборот
# 0  Палки для скандинавской ходьбы    354900
# 1   Палки для скандинавской ходьбы   768000
# 2  Палки для скандинавской ходьбы   1892800
# 3                            Гамак    31080
# 4                    Электрошокер    629600

# %%
df = df.sort_values(by=['Оборот'], ascending=False)

# %%
df.head(20)
# Out:
#      Цена с промокодом  Отзывов  Рейтинг  Вопросов  \
# 7                15750       30      5.0        22
# 73                1990      162      4.8        51
# 14                 274      563      4.4        63
# 20                 812      186      4.8        30
# 18                1471      109      4.8        23
# 91                3880       36      4.6         9
# 2                 1183       85      4.3         0
# 33                1259       98      4.6        51
# 116               2340       40      4.8        21
# 48                1200       49      4.8        14
# 46                 441      189      4.6        32
# 71                 532      116      4.7        21
# 57                1207       33      4.1        10
# 77                 844       54      4.2        15
# 69                2274       16      4.9        12
# 9                  995       72      4.4        16
# 112               4338       16      4.4        13
# ...

# %%
df = df[['Цена с промокодом', 'Отзывов', 'Рейтинг', 'Вопросов', 'Название', 'Оборот']]

# %%
df["Название"] = df["Название"].apply(lambda x: x.strip())

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
turnover = df['Оборот']
del df['Оборот']

# %%
df = pd.get_dummies(df, columns= ['Название'])

# %%
df
# Out:
#      Цена с промокодом  Отзывов  Рейтинг  Вопросов  Название_Бинокль  \
# 7                15750       30      5.0        22                 0
# 73                1990      162      4.8        51                 0
# 14                 274      563      4.4        63                 0
# 20                 812      186      4.8        30                 0
# 18                1471      109      4.8        23                 0
# ..                 ...      ...      ...       ...               ...
# 108               1110        4      4.2         0                 0
# 82                1068        2      5.0         0                 0
# 96                1580        3      5.0         0                 0
# 139                957        5      5.0         0                 0
# 87                 779        3      5.0         0                 1
#
#      Название_Водонепроницаемый чехол  Название_Гамак  Название_Гамаши  \
# ...

# %%
X_train =  df.values
y_train = turnover.values

# %%
columns = df.columns

# %%
len(df.columns)
# Out:
# 19

# %%
#X_train, X_test, y_train, y_test = train_test_split(df, turnover, test_size=0.01)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 4.60220895e+01,  2.18901507e+03,  1.37244220e+05,  2.93989473e+04,
#        -1.73283249e+05, -2.30232021e+05, -6.63102932e+04, -2.69298489e+05,
#        -4.26419089e+05,  1.11620389e+06, -3.77672752e+05, -1.75446021e+05,
#        -1.55425464e+05, -1.76143990e+05,  8.88195773e+04,  4.70522983e+05,
#         3.05666823e+05,  1.38414302e+05, -6.93962083e+04])

# %%
importance = model.coef_

# %%
importance
# Out:
# array([ 4.60220895e+01,  2.18901507e+03,  1.37244220e+05,  2.93989473e+04,
#        -1.73283249e+05, -2.30232021e+05, -6.63102932e+04, -2.69298489e+05,
#        -4.26419089e+05,  1.11620389e+06, -3.77672752e+05, -1.75446021e+05,
#        -1.55425464e+05, -1.76143990e+05,  8.88195773e+04,  4.70522983e+05,
#         3.05666823e+05,  1.38414302e+05, -6.93962083e+04])

# %%
features = []
for i,v in enumerate(importance):
    features.append((columns[i], v))
    features.sort(key=lambda x: x[1], reverse=True)
for name, val in  features:
    print('Feature: %0s, Score: %.2f' % (name,val))
# Out:
# Feature: Название_Лопата, Score: 1116203.89
# Feature: Название_Палки для скандинавской ходьбы, Score: 470522.98
# Feature: Название_Рюкзак, Score: 305666.82
# Feature: Название_Фонарь, Score: 138414.30
# Feature: Рейтинг, Score: 137244.22
# Feature: Название_Органайзер для кабелей, Score: 88819.58
# Feature: Вопросов, Score: 29398.95
# Feature: Отзывов, Score: 2189.02
# Feature: Цена с промокодом, Score: 46.02
# Feature: Название_Гамак, Score: -66310.29
# Feature: Название_Электрошокер, Score: -69396.21
# Feature: Название_Налобный фонарь, Score: -155425.46
# Feature: Название_Бинокль, Score: -173283.25
# Feature: Название_Набор для выживания, Score: -175446.02
# Feature: Название_Нож, Score: -176143.99
# Feature: Название_Водонепроницаемый чехол, Score: -230232.02
# Feature: Название_Гамаши, Score: -269298.49
# Feature: Название_Мачете, Score: -377672.75
# Feature: Название_Дорожные органайзеры, Score: -426419.09

# %%
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %% [markdown]
# !!!!

# %%
df = pd.read_excel('Аксессуары туризм1.xlsx')
df['Оборот'] = df['Цена с промокодом'] * df['Покупок']

# %%
df["Название"] = df["Название"].apply(lambda x: x.strip())

# %%
df = df[['Цена с промокодом', 'Отзывов', 'Рейтинг', 'Вопросов', 'Продавец', 'Название', 'Оборот']]

# %%
df.head()
# Out:
#    Цена с промокодом  Отзывов  Рейтинг  Вопросов  \
# 0               1183       85      4.3         0
# 1                960       71      4.2         0
# 2               1183       85      4.3         0
# 3               1554        1      2.0         0
# 4                787       63      4.4         0
#
#                                             Продавец  \
# 0                    Черкасских Олег Владимирович ИП
# 1                    Черкасских Олег Владимирович ИП
# 2                    Черкасских Олег Владимирович ИП
# 3  Индивидуальный предприниматель Родькин Алексей...
# 4                      Прохоров Андрей Дмитриевич ИП
#
#                          Название   Оборот
# 0  Палки для скандинавской ходьбы   354900
# 1  Палки для скандинавской ходьбы   768000
# 2  Палки для скандинавской ходьбы  1892800
# 3                           Гамак    31080
# 4                    Электрошокер   629600

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
turnover = df['Оборот']
del df['Оборот']

# %%
df = pd.get_dummies(df, columns= ['Продавец', 'Название'])

# %%
X_train =  df.values
y_train = turnover.values

# %%
X_train.shape
# Out:
# (150, 66)

# %%
#X_train, X_test, y_train, y_test = train_test_split(df, turnover, test_size=0.01)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
len(df.columns)
# Out:
# 66

# %%
importance = model.coef_

# %%
columns = df.columns

# %%
model.coef_
# Out:
# array([ 2.42387636e-01,  3.62042795e+03,  1.82704052e+04,  1.33319916e+04,
#         4.20543377e+06, -3.23113944e+05, -1.68946803e+05, -7.73972828e+05,
#        -1.59480108e+05, -6.20228682e+04, -8.33250982e+05, -3.29314129e+05,
#        -6.78693610e+05, -3.55413121e+05, -3.42957517e+05, -2.75647405e+05,
#        -2.15669075e+05, -8.83538017e+04, -8.06150335e+05, -4.82310941e+04,
#         1.65879959e+05,  4.81019355e+04,  5.04419656e+06, -1.08899606e+05,
#        -2.63134107e+05, -1.47745085e+05, -5.95558812e+05, -8.82419400e+04,
#        -3.13862817e+05, -3.50540116e+05, -3.83966458e+05,  1.29936552e+06,
#        -2.12498091e+05, -3.42339080e+05, -2.85478344e+05,  3.68736661e+05,
#        -6.41833693e+04, -6.74304892e+05,  3.24126214e+05, -2.82393692e+05,
#         1.79159894e+05,  6.19816247e+04, -3.91442760e+05, -7.37158394e+05,
#        -1.76309239e+05, -1.72102191e+05,  2.35540319e+05, -6.58326551e+05,
# ...

# %%
len(columns), len(importance)
# Out:
# (66, 66)

# %%
features = []
for i,v in enumerate(importance):
    features.append((columns[i], v))
    features.sort(key=lambda x: x[1], reverse=True)
for name, val in  features:
    print('Feature: %0s, Score: %.2f' % (name,val))
# Out:
# Feature: Продавец_Кудряшов Григорий Константинович ИП, Score: 5044196.56
# Feature: Продавец_АРГОС ООО (7816135125), Score: 4205433.77
# Feature: Продавец_ООО МИР, Score: 1299365.52
# Feature: Название_Лопата, Score: 529444.59
# Feature: Название_Бинокль, Score: 506250.29
# Feature: Продавец_Общество с ограниченной ответственностью "МЕРКУРИЙ ТРЕЙДИНГ", Score: 368736.66
# Feature: Продавец_Павленко Алексей Анатольевич ИП, Score: 324126.21
# Feature: Продавец_Черкасских Олег Владимирович ИП, Score: 235540.32
# Feature: Продавец_Прохоров Андрей Дмитриевич ИП, Score: 179159.89
# Feature: Название_Палки для скандинавской ходьбы, Score: 171356.95
# Feature: Продавец_Кожемякин Виталий Константинович ИП, Score: 165879.96
# Feature: Продавец_Энергосистемы и Технологии АО, Score: 127556.32
# Feature: Продавец_РИТЕЙЛ ООО, Score: 61981.62
# Feature: Продавец_Крыжановская Елена Борисовна ИП, Score: 48101.94
# Feature: Название_Нож, Score: 30181.05
# Feature: Рейтинг, Score: 18270.41
# ...

# %%
plt.bar([x for x in range(len(importance))], importance)
plt.show()
